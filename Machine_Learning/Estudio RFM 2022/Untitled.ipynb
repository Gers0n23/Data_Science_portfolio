# %%
import pandas as pd

# %%
main_path = 'C:/Users/juan.vergara/OneDrive - Caren Repuestos Flotacentro/Documentos/Análisis/Segmentación Clientes/'

df_excel = pd.read_excel(main_path + 'clientes calientes enero.xlsx', sheet_name='Contactos')

# %%
df_excel.head()
# Out:
#          ID                  nombre  apellidos  descripción empresa titulo  \
# 0  10119097           MOVIMIENTO SPA       NaN          NaN   MOVSA    NaN
# 1  10119098                 10119289       NaN          NaN     NaN    NaN
# 2  10119101    COMERCIAL SP LIMITADA       NaN          NaN     NaN    NaN
# 3  10119119  DISTR.NEUM.DEL SUR LTDA       NaN          NaN   DACSA    NaN
# 4  10119125                 10119125       NaN          NaN  ADBLUE    NaN
#
#        propietario origen tipo  sector  ... Ctf-Net Utm-Source Ctf-Ad Gclid  \
# 0  Interaction SPA    NaN  NaN     NaN  ...     NaN        NaN    NaN   NaN
# 1  Interaction SPA    NaN  NaN     NaN  ...     NaN        NaN    NaN   NaN
# 2  Interaction SPA    NaN  NaN     NaN  ...     NaN        NaN    NaN   NaN
# 3  Interaction SPA    NaN  NaN     NaN  ...     NaN        NaN    NaN   NaN
# 4  Interaction SPA    NaN  NaN     NaN  ...     NaN        NaN    NaN   NaN
#
# ...

# %%
df_excel = df_excel[['ID','nombre ','email 1','teléfono 1']]

# %%
df_excel.columns = ['ID','nombre ','Email SAAD','teléfono 1']

# %%
df_excel.head()
# Out:
#          ID                  nombre                          Email SAAD  \
# 0  10119097           MOVIMIENTO SPA                    israel@movsa.cl
# 1  10119098                 10119289                      lcofre@sdn.cl
# 2  10119101    COMERCIAL SP LIMITADA  ventasdistribuidor@comercialsp.cl
# 3  10119119  DISTR.NEUM.DEL SUR LTDA              dacsaosorno@gmail.com
# 4  10119125                 10119125                m.torres@adquim.com
#
#                                           teléfono 1
# 0                                    +56 9 5530 6433
# 1         +56 22 487 0020 / Central  +56 22 487 0000
# 2                                                NaN
# 3  Telf. Temuco 45 2 200800_TELEF.  64  2 312121 ...
# 4                                                NaN

# %%
dir_path = 'C:/Users/juan.vergara/OneDrive - Caren Repuestos Flotacentro/Documentos/Análisis/Parque Automotriz/Parque en Bruto para Modelo/Direcciones/'

# %%
df_dir = pd.read_csv(dir_path + 'df_rut_direcciones_comunasregion.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (8,9,10,19) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_dir.head()
# Out:
#    RUT                  REGION DOMICILIO COMUNA DOMICILIO   Provincia  \
# 0   68                                 0                0         NaN
# 1  206                                 0                0         NaN
# 2  235  Región Metropolitana de Santiago         SANTIAGO    Santiago
# 3  240               Región de Los Lagos     PUERTO MONTT  Llanquihue
# 4  245                                 0                0         NaN
#
#      Latitud   Longitud Sucursal Caren Sucursal Caren Ampliada CALLE NUMERO  \
# 0        NaN        NaN            NaN                     NaN   NaN    NaN
# 1        NaN        NaN            NaN                     NaN   NaN    NaN
# 2   -33,2614   -70,3926       Santiago                Santiago   NaN    NaN
# 3  -41,27144  -72,59348   Puerto Montt            Puerto Montt   NaN    NaN
# 4        NaN        NaN            NaN                     NaN   NaN    NaN
#
#    ... fono2 2019             mail 2020  fono1 2020  fono2 2020 fono3 2020  \
# ...

# %%
df_dir = df_dir[['RUT','mail 2020','mail 2019','Email SAAD']]

# %%
df_dir.head()
# Out:
#    RUT             mail 2020             mail 2019 Email SAAD
# 0   68                     0                   NaN        NaN
# 1  206                     0                   NaN        NaN
# 2  235  borixito@hotmail.com  borixito@hotmail.com        NaN
# 3  240                     0                   NaN        NaN
# 4  245                     0                   NaN        NaN

# %%
df_mail_rut = pd.merge(df_excel, df_dir, on = 'Email SAAD', how = 'left')

# %%
df_mail_rut
