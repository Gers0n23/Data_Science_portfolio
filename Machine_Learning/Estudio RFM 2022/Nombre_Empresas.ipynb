# %%
import pandas as pd

# %%
URL = 'C:/Users/juan.vergara/OneDrive - Caren Repuestos Flotacentro/Documentos/Análisis/Parque Automotriz/Parque en Bruto para Modelo/'

# %%
df_p = pd.read_csv(URL + 'ParqueAutomotriz2020_Modelo.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (15) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_p[df_p['RUT_Final'] == 74687374]
# Out:
#             ppu dv_ppu  ano_fab     color             motor  \
# 375321   JD4397      0     1993      AZUL               NaN
# 377357   JN4554      6     2013    BLANCO               NaN
# 377358   JN4555      4     2013    BLANCO               NaN
# 377359   JN4556      2     2013    BLANCO               NaN
# 386626   JD8398      0     1996      AZUL               NaN
# 414511   JK2338      1     2011    BLANCO               NaN
# 414512   JK2339      K     2011    BLANCO               NaN
# 425644   JK3413      8     2009    BLANCO               NaN
# 425645   JK3414      6     2009    BLANCO               NaN
# 425646   JK3415      4     2009    BLANCO               NaN
# 443939   JK8326      0     2010    BLANCO               NaN
# 443940   JK8327      9     2010    BLANCO               NaN
# 443941   JK8328      7     2010    BLANCO               NaN
# 457989   JL2467      6     2011    BLANCO               NaN
# 457990   JL2468      4     2011    BLANCO               NaN
# ...

# %%
df_p = df_p[['RUT_Final','nomtot']]

# %%
df_p[df_p['RUT_Final'] == 74687374]
# Out:
#          RUT_Final                                    nomtot
# 375321    74687374  SERVICIOS GENERALES PRAT Y WILLIAMS LTDA
# 377357    74687374  SERVICIOS GENERALES PRAT Y WILLIAMS LTDA
# 377358    74687374  SERVICIOS GENERALES PRAT Y WILLIAMS LTDA
# 377359    74687374  SERVICIOS GENERALES PRAT Y WILLIAMS LTDA
# 386626    74687374  EXPORTACION, EXTRACCION Y COMERCIALIZACI
# 414511    74687374  SERVICIOS GENERALES PRAT Y WILLIAMS LTDA
# 414512    74687374  SERVICIOS GENERALES PRAT Y WILLIAMS LTDA
# 425644    74687374  SERVICIOS GENERALES PRAT Y WILLIAMS LTDA
# 425645    74687374  SERVICIOS GENERALES PRAT Y WILLIAMS LTDA
# 425646    74687374  SERVICIOS GENERALES PRAT Y WILLIAMS LTDA
# 443939    74687374  SERVICIOS GENERALES PRAT Y WILLIAMS LTDA
# 443940    74687374  SERVICIOS GENERALES PRAT Y WILLIAMS LTDA
# 443941    74687374  SERVICIOS GENERALES PRAT Y WILLIAMS LTDA
# 457989    74687374  SERVICIOS GENERALES PRAT Y WILLIAMS LTDA
# ...

# %%
df_p.shape
# Out:
# (7842085, 2)

# %%
df_p.head()
# Out:
#    RUT_Final                               nomtot
# 0    9629390        SEGURA CASTILLO RAMON SEGUNDO
# 1    3222026              PAILLAMAN COTAR TORIBIO
# 2    8937861       SALAS CORTES CRISTIAN HUMBERTO
# 3   10077682            PALMA SILVA DAVID IGNACIO
# 4   15745597  FUENTES ZUNIGA UBERLINDA DEL CARMEN

# %%
df_p = df_p.drop_duplicates()

# %%
df_p.shape
# Out:
# (4855040, 2)

# %%
df_final = df_p.groupby(['RUT_Final'])['nomtot'].first().reset_index()

# %%
df_final.head()
# Out:
#    RUT_Final                        nomtot
# 0          0                          None
# 1        235     ALESSANDRI VALDES GUSTAVO
# 2        771       JOANNON INFANTE ALBERTO
# 3        884  VALENZUELA OZU CARMEN SUSANA
# 4        957  VEGA COLLAO PATRICIA EUGENIA

# %%
df_final.shape
# Out:
# (4853895, 2)

# %%
df_rut = df_final['RUT_Final'].drop_duplicates()
df_rut.shape
# Out:
# (4853895,)

# %%
df_final[df_final['RUT_Final'] == 74687374]
# Out:
#          RUT_Final                                    nomtot
# 4650366   74687374  SERVICIOS GENERALES PRAT Y WILLIAMS LTDA

# %%
#FINAL

df_final.to_csv(URL+'Nombres_Clientes.csv', index = False)
