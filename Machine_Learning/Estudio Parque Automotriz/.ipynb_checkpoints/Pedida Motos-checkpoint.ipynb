# %%
import pandas as pd

# %%
path = 'C:/Users/juan.vergara/OneDrive - Caren Repuestos Flotacentro/Documentos/Análisis/Parque Automotriz/Parque en Bruto para Modelo/'
df_parque = pd.read_csv(path + 'ParqueAutomotriz2020_Modelo.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (15) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_parque.head()
# Out:
#       ppu dv_ppu  ano_fab  color    motor             chasis       rut dv  \
# 0  AC9316      7     1993  NEGRO  2323226            1305579   9629390  9
# 1  AC9317      5     1993   AZUL   235034  TFR16HDL-E-B-1471   3222026  6
# 2  AC9318      3     1993  BEIGE     1635             874207   8937861  3
# 3  AC9319      1     1993   ROJO   237353    TFS16HDL-E-0423  10077682  0
# 4  AC9320      5     1993   AZUL   232862  TFR16HDL-E-B-1354  15745597  4
#
#                                 nomtot tp_motor_fantasia  ...  \
# 0        SEGURA CASTILLO RAMON SEGUNDO               NaN  ...
# 1              PAILLAMAN COTAR TORIBIO               NaN  ...
# 2       SALAS CORTES CRISTIAN HUMBERTO               NaN  ...
# 3            PALMA SILVA DAVID IGNACIO               NaN  ...
# 4  FUENTES ZUNIGA UBERLINDA DEL CARMEN               NaN  ...
#
#                 Modelo lmat_vigencia Consumo_Teorico_Lubricantes  \
# 0            21053 1.5           NaN                           0
# ...

# %%
df_parque = df_parque[df_parque['Tipo'] == 'MOTO']

# %%
df_parque.head()
# Out:
#        ppu dv_ppu  ano_fab     color          motor        chasis       rut  \
# 29  AA0197      4     1990     NEGRO     3TS-002771    3TS-002771   8789954
# 30  AA0486      8     1990    BLANCO        1009326        604820  10182771
# 31  AA0487      6     1992    BLANCO        5601822       5600115   9290864
# 32  AA0494      9     1992  AMARILLO     3GX-012094    3GX-012094   8676036
# 33  AA0546      5     1992    BLANCO  TA01E-1602551  TA02-1102525  11709201
#
#    dv                              nomtot tp_motor_fantasia  ...  \
# 29  3           VELIZ VELIZ JAIME EDUARDO               NaN  ...
# 30  2           CORREA NAUPA JOSE ENRIQUE               NaN  ...
# 31  K              DIAZ MORA MARIA ALICIA               NaN  ...
# 32  3  DIAZ MONTECINO GABRIELA DEL CARMEN               NaN  ...
# 33  1      FEEST PUSCHEL BERNARDO ALBERTO               NaN  ...
#
#                Modelo lmat_vigencia Consumo_Teorico_Lubricantes  \
# ...

# %%
df_parque.columns
# Out:
# Index(['ppu', 'dv_ppu', 'ano_fab', 'color', 'motor', 'chasis', 'rut', 'dv',
#        'nomtot', 'tp_motor_fantasia', 'tp_marcaMotor', 'tp_vigencia', 'Marca',
#        'Tipo', 'Modelo', 'lmat_vigencia', 'Consumo_Teorico_Lubricantes',
#        'Consumo_Teorico_Neumaticos', 'Consumo_Teorico_Repuestos',
#        'Consumo_Teorico_Repuestos_TM', 'Consumo_Teorico_Total', 'RUT_Final',
#        'mantencion', 'leasing'],
#       dtype='object')

# %%
df_parque = df_parque[['ppu', 'dv_ppu', 'ano_fab', 'color', 'motor', 'chasis','Marca','Modelo']]

# %%
df_parque.head()
# Out:
#        ppu dv_ppu  ano_fab     color          motor        chasis   Marca  \
# 29  AA0197      4     1990     NEGRO     3TS-002771    3TS-002771  YAMAHA
# 30  AA0486      8     1990    BLANCO        1009326        604820   HONDA
# 31  AA0487      6     1992    BLANCO        5601822       5600115   HONDA
# 32  AA0494      9     1992  AMARILLO     3GX-012094    3GX-012094  YAMAHA
# 33  AA0546      5     1992    BLANCO  TA01E-1602551  TA02-1102525   HONDA
#
#                Modelo
# 29             DT 175
# 30        XL 125 DUTY
# 31          XR 200 RM
# 32             AG 200
# 33  GYRO CANOPY 50 CC

# %%
df_parque.shape
# Out:
# (551911, 8)

# %%
df_parque.to_csv(path + 'BBDD_Motos.csv', index = False)
